# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/kittyschulz/scraped_image_classification/blob/main/scrape_and_classify.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !git clone https://github.com/kittyschulz/scraped_image_classification.git
# Out:
# Cloning into 'scraped_image_classification'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 19 (delta 5), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (19/19), 8.30 KiB | 8.30 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %%capture
# This may take a while...
# !pip install -r ./scraped_image_classification/requirements.txt

# %%
from scraped_image_classification.scrape import *
from scraped_image_classification.classify import *

# %%
# @title Scrape Images from Google { run: "auto", vertical-output: true }

image_label_1 = "lizard" # @param {type:"string"}
image_label_2 = "cheeseburger" # @param {type:"string"}
image_label_3 = "traffic light" # @param {type:"string"}
num_images = 3 # @param {type:"integer"}

scrape_google_images(image_label_1, num_images)
scrape_google_images(image_label_2, num_images)
scrape_google_images(image_label_3, num_images)

# %%
# @title Visualize a Sample of Scraped Imagery

visualize_sample_images(['lizard', 'cheeseburger', 'traffic light'])

# %%
# @title Run Inference on Scraped Imagery

df = predict_scraped_images([image_label_1, image_label_2, image_label_3])
df.head(9)
# Out:
# ...
# 114235032/114235032 [==============================] - 1s 0us/step
# >>>> Load pretrained from: /root/.keras/models/davit_t_imagenet.h5
# >>>> Trying to load index file: /root/.keras/datasets/imagenet_class_index.json
# ...
# 35363/35363 [==============================] - 0s 0us/step
# Classification results saved to classification_results.xlsx
#             Image Name  Classification  Confidence
# 0         lizard_1.jpg    Banded Gecko    0.017894
# 1         lizard_3.jpg  Frilled Lizard    0.144657
# 2         lizard_2.jpg   Common Iguana    0.087524
# 3   cheeseburger_3.jpg    Cheeseburger    0.191373
# 4   cheeseburger_1.jpg    Cheeseburger    0.296457
# 5   cheeseburger_2.jpg    Cheeseburger    0.132211
# 6  traffic_light_1.jpg   Traffic Light    0.178881
# 7  traffic_light_2.jpg   Traffic Light    0.109060
# 8  traffic_light_3.jpg   Traffic Light    0.223533

# %%
# @title Visualize Predictions

plot_random_images_with_class(df)
